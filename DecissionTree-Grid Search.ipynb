# %%
import pandas as pd
data = pd.read_csv("insurance_pre.csv")
data
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
data = pd.get_dummies(data,drop_first=True)
data
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
independent = data[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent = data[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'splitter':['random','best'],'criterion':['squared_error','absolute_error','friedman_mse','poisson'],'max_features':['auto','sqrt','log2']}
grid = GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 22 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 18 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.64918141 0.67586221 0.65350549 0.70888185
#         nan        nan 0.70388361 0.61474182 0.66183966 0.61783239
#         nan        nan 0.66953048 0.63608289 0.63770233 0.66746815
#         nan        nan 0.64294391 0.69291087 0.63808833 0.69415339]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['random', 'best']},
#              verbose=3)

# %%
re = grid.cv_results_ 
print("The R_score value of the best parameter is {}:".format(grid.best_params_))
# Out:
# The R_score value of the best parameter is {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'}:

# %%
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000000      0.000000         0.000000        0.000000
# 1        0.003306      0.005665         0.000000        0.000000
# 2        0.014348      0.005444         0.013552        0.012297
# 3        0.013490      0.002792         0.007909        0.008236
# 4        0.004894      0.005837         0.013192        0.018212
# 5        0.014664      0.001652         0.001119        0.001746
# 6        0.000200      0.000399         0.000000        0.000000
# 7        0.003338      0.006158         0.000000        0.000000
# 8        0.041704      0.011949         0.012252        0.012811
# 9        0.068844      0.018970         0.006211        0.006084
# 10       0.040598      0.013874         0.010799        0.006328
# 11       0.060644      0.013923         0.004781        0.003403
# 12       0.004528      0.006178         0.000000        0.000000
# 13       0.000400      0.000800         0.000000        0.000000
# 14       0.014626      0.003898         0.001302        0.002604
# 15       0.010239      0.005532         0.008155        0.006393
# 16       0.006408      0.005246         0.009048        0.006078
# 17       0.015554      0.004880         0.001809        0.002256
# 18       0.000000      0.000000         0.000000        0.000000
# 19       0.001399      0.001958         0.000000        0.000000
# 20       0.016070      0.000502         0.000000        0.000000
# 21       0.013795      0.003396         0.005361        0.006608
# 22       0.005932      0.007283         0.005408        0.006653
# 23       0.010164      0.006024         0.010214        0.003729
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               auto         random
# 1    squared_error               auto           best
# 2    squared_error               sqrt         random
# 3    squared_error               sqrt           best
# 4    squared_error               log2         random
# 5    squared_error               log2           best
# 6   absolute_error               auto         random
# 7   absolute_error               auto           best
# 8   absolute_error               sqrt         random
# 9   absolute_error               sqrt           best
# 10  absolute_error               log2         random
# 11  absolute_error               log2           best
# 12    friedman_mse               auto         random
# 13    friedman_mse               auto           best
# 14    friedman_mse               sqrt         random
# 15    friedman_mse               sqrt           best
# 16    friedman_mse               log2         random
# 17    friedman_mse               log2           best
# 18         poisson               auto         random
# 19         poisson               auto           best
# 20         poisson               sqrt         random
# 21         poisson               sqrt           best
# 22         poisson               log2         random
# 23         poisson               log2           best
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.656535
# 3   {'criterion': 'squared_error', 'max_features':...           0.621654
# 4   {'criterion': 'squared_error', 'max_features':...           0.693242
# 5   {'criterion': 'squared_error', 'max_features':...           0.753713
# 6   {'criterion': 'absolute_error', 'max_features'...                NaN
# 7   {'criterion': 'absolute_error', 'max_features'...                NaN
# 8   {'criterion': 'absolute_error', 'max_features'...           0.689600
# 9   {'criterion': 'absolute_error', 'max_features'...           0.601632
# 10  {'criterion': 'absolute_error', 'max_features'...           0.759434
# 11  {'criterion': 'absolute_error', 'max_features'...           0.674563
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.591249
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.777524
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.631325
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.711391
# 18  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'auto...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.690530
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.720620
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.689529
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.774673
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.572660           0.667068           0.694520
# 3            0.649054           0.689359           0.703415
# 4            0.570797           0.651372           0.667584
# 5            0.675104           0.718766           0.702989
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.639450           0.750380           0.717075
# 9            0.554741           0.591058           0.616806
# 10           0.632472           0.662452           0.688134
# 11           0.509597           0.569013           0.632036
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.594124           0.718292           0.722241
# 15           0.501189           0.685477           0.566644
# 16           0.480782           0.697285           0.671859
# 17           0.589443           0.759313           0.668564
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.491681           0.651273           0.688928
# 21           0.608479           0.706314           0.735572
# 22           0.547064           0.554526           0.643107
# 23           0.598794           0.688154           0.675949
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.655124         0.649181        0.040793               10
# 3            0.715830         0.675862        0.035202                5
# 4            0.684533         0.653505        0.043784                9
# 5            0.693838         0.708882        0.026493                1
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.722913         0.703884        0.037560                2
# 9            0.709472         0.614742        0.051597               16
# 10           0.566706         0.661840        0.063450                8
# 11           0.703954         0.617832        0.070619               15
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.721747         0.669530        0.062764                6
# 15           0.649580         0.636083        0.095546               14
# 16           0.707261         0.637702        0.082728               13
# 17           0.608629         0.667468        0.063112                7
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.692308         0.642944        0.077156               11
# 21           0.693569         0.692911        0.044489                4
# 22           0.756216         0.638088        0.079867               12
# 23           0.733197         0.694153        0.059108                3
